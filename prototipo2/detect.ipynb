# %% [markdown]
# # Pruebas de la función Detect del segundo prototipo
#
# Integración con la generación de exámenes de pyexams.
# Desde el directorio multiple_choice_example", ejecuto el siguiente comando:
#
# "pyexams test_qr.tex -both -all"
#
# que genera los JSON de enunciado y solución siguientes:

# %%
# JSON DEL ENUNCIADO
json_question1 = "json/question_11111.json"
json_question2 = "json/question_22222.json"
json_question3 = "json/question_33333.json"
json_question4 = "json/question_44444.json"
# JSON DE LA SOLUCIÓN
json_solution1 = "json/solution_11111.json"
json_solution2 = "json/solution_22222.json"
json_solution3 = "json/solution_33333.json"
json_solution4 = "json/solution_44444.json"

# %%
import json

# %%
with open(json_question1) as json_file:
    question1 = json.load(json_file)
question1
# Out:
# {'exam': 'test_qr',
#  'variant': '11111',
#  'num_boxes': 67,
#  'exercises': [{'exercise': 'vf1',
#    'checkboxes': [{'checkbox': '0,0',
#      'cords': [105.961, 383.659, 12.716, 12.716],
#      'page': 1},
#     {'checkbox': '0,1',
#      'cords': [105.961, 367.719, 12.716, 12.716],
#      'page': 1}]},
#   {'exercise': 'vf2',
#    'checkboxes': [{'checkbox': '1,0',
#      'cords': [105.961, 324.103, 12.716, 12.717],
#      'page': 1},
#     {'checkbox': '1,1',
#      'cords': [105.961, 308.163, 12.716, 12.716],
#      'page': 1}]},
#   {'exercise': 'vf3',
#    'checkboxes': [{'checkbox': '2,0',
#      'cords': [105.961, 265.739, 12.716, 12.716],
#      'page': 1},
#     {'checkbox': '2,1',
#      'cords': [105.961, 249.799, 12.716, 12.716],
#      'page': 1}]},
#   {'exercise': 'vf4',
#    'checkboxes': [{'checkbox': '3,0',
#      'cords': [105.961, 207.375, 12.716, 12.716],
#      'page': 1},
#     {'checkbox': '3,1',
#      'cords': [105.961, 191.434, 12.716, 12.717],
# ...

# %%
with open(json_solution1) as json_file:
    solution1 = json.load(json_file)
solution1
# Out:
# {'exam': 'test_qr',
#  'variant': '11111',
#  'num_boxes': 67,
#  'exercises': [{'exercise': 'vf1',
#    'checkboxes': [{'checkbox': '0,0',
#      'cords': [105.961, 401.272, 12.716, 12.716],
#      'page': 1,
#      'is_marked': True},
#     {'checkbox': '0,1',
#      'cords': [105.961, 385.332, 12.716, 12.716],
#      'page': 1,
#      'is_marked': False}],
#    'sol_marked': ['0,0']},
#   {'exercise': 'vf2',
#    'checkboxes': [{'checkbox': '1,0',
#      'cords': [105.961, 341.717, 12.716, 12.716],
#      'page': 1,
#      'is_marked': True},
#     {'checkbox': '1,1',
#      'cords': [105.961, 325.776, 12.716, 12.716],
#      'page': 1,
#      'is_marked': False}],
#    'sol_marked': ['1,0']},
#   {'exercise': 'vf3',
#    'checkboxes': [{'checkbox': '2,0',
#      'cords': [105.961, 283.352, 12.716, 12.716],
#      'page': 1,
#      'is_marked': True},
#     {'checkbox': '2,1',
#      'cords': [105.961, 267.412, 12.716, 12.716],
#      'page': 1,
#      'is_marked': False}],
# ...

# %% [markdown]
# # Analizar con rotaciones

# %%
from scan import analyse

# %% [markdown]
# ## Directorio de trabajo
#
# cambiar el directorio al del examen de pruebas, para tener acceso a los pdf y json sin copiar

# %%
import os
os.chdir('../multiple_choice_example')

# %%
analyse('scanned/scanned_22222_rot90.pdf', verbose=True)
analyse('scanned/scanned_22222_rot180.pdf', verbose=True)
# Out:
# Correcting file scanned/scanned_22222_rot90.pdf
# Looking for QR codes
# Looking for statement JSON file
# Statement JSON file found
# Looking for solution JSON file
# Solution JSON file found
# Extracting boxes with OpenCV
# Analysing page 0
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 1
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 2
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Grading the exam
# Number of correct exercises: 8/20
# Correcting file scanned/scanned_22222_rot180.pdf
# Looking for QR codes
# Looking for statement JSON file
# Statement JSON file found
# Looking for solution JSON file
# Solution JSON file found
# Extracting boxes with OpenCV
# Analysing page 0
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 1
# Preprocessing the page
# ...

# %% [markdown]
# ### Corregir examen girado 45º
#
# Como demostración, corregir este examen
# Con dpi distinto (si no no reconoce uno de los qr)
# No reconoce las casillas, estan demasiado giradas para que el filtro no las borre

# %%
analyse('scanned/scanned_22222_rot45.pdf', verbose=True, dpi=300)
# Out:
# Correcting file scanned/scanned_22222_rot45.pdf
# Looking for QR codes
# Looking for statement JSON file
# Statement JSON file found
# Looking for solution JSON file
# Solution JSON file found
# Extracting boxes with OpenCV
# Analysing page 0
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 1
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 2
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Grading the exam
# Number of correct exercises: 0/20

# %%
from scan import analyse_dir

# %% [markdown]
# ## Directorio de trabajo
#
# cambiar el directorio al del examen de pruebas, para tener acceso a los pdf y json sin copiar

# %%
import os
os.chdir('../multiple_choice_example')

# %% [markdown]
# # Analizar carpeta
#
# Carpeta con las variantes rellenadas a mano (11111, 22222) y a ordenador (33333, 44444), versiones sin rotar

# %%
file = 'do_folder'
analyse_dir(file, verbose=True)
# Out:
# Correcting exams in directory: do_folder
# Found file: do_folder/scanned_11111.pdf
# Correcting file do_folder/scanned_11111.pdf
# Looking for QR codes
# Looking for statement JSON file
# Statement JSON file found
# Looking for solution JSON file
# Solution JSON file found
# Extracting boxes with OpenCV
# Analysing page 0
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 1
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Analysing page 2
# Preprocessing the page
# Looking for the AMC circles
# Looking for the expected checkboxes
# Grading the exam
# Number of correct exercises: 9/20
# Found file: do_folder/scanned_22222.pdf
# Correcting file do_folder/scanned_22222.pdf
# Looking for QR codes
# Looking for statement JSON file
# Statement JSON file found
# Looking for solution JSON file
# Solution JSON file found
# Extracting boxes with OpenCV
# Analysing page 0
# ...

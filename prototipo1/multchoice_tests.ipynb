# %% [markdown]
# # Pruebas con el nuevo examen
#
# Con version rellenada a mano y version rellenada con ordenador

# %%
import json
from scan import detect_st, detect_sol, detect_fill
from scan import analyse, match

# %%
file_question1 = '../multiple_choice_example/question/question_11111.pdf'
file_solution1 = '../multiple_choice_example/solution/solution_11111.pdf'
file_scanned1 = '../multiple_choice_example/scanned/scanned_11111.pdf'

file_question3 = '../multiple_choice_example/question/question_33333.pdf'
file_solution3 = '../multiple_choice_example/solution/solution_33333.pdf'
file_filled3 = '../multiple_choice_example/filled/filled_33333.pdf'

json_question1 = 'json/st_multchoice1.json'
json_question3 = 'json/st_multchoice3.json'
json_solution1 = 'json/sol_multchoice1.json'
json_solution3 = 'json/sol_multchoice3.json'

# %% [markdown]
# ## Detect

# %%
detect_st(file_question1, "multchoice1")
detect_st(file_question3, "multchoice3")

detect_sol(file_solution1, json_question1, '11111')
detect_sol(file_solution1, json_question3, '33333')

# %% [markdown]
# ## Analyse

# %%
detect_fill(file_filled3, json_question3, '33333')

# %%
analyse(file_scanned1, json_question1, '11111')
# Out:
# 67 31
# Error, numero de casillas distinto

# %% [markdown]
# las casillas encontradas son distintas, voy a ver qué encuentra

# %%
analyse(file_scanned1, json_question1, '11111', draw=True)
# Out:
# 67 31
# Error, numero de casillas distinto
